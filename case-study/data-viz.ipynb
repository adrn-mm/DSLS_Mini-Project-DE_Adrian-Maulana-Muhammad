# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_product_analysis_1 = pd.read_csv('product_analysis_1.csv', delimiter=';')
df_product_analysis_2 = pd.read_csv('product_analysis_2.csv', delimiter=';')
df_customer_analysis_1 = pd.read_csv('customer_analysis_1.csv', delimiter=';')
df_customer_analysis_2 = pd.read_csv('customer_analysis_2.csv', delimiter=';')
df_shipper_analysis_1 = pd.read_csv('shipper_analysis_1.csv', delimiter=';')
df_shipper_analysis_2 = pd.read_csv('shipper_analysis_2.csv', delimiter=';')

# %%
df_customer_analysis_2
# Out:
#                     CompanyName  OrderCount
# 0            Save-a-lot Markets          31
# 1                  Ernst Handel          30
# 2                    QUICK-Stop          28
# 3                Folk och fä HB          19
# 4  Hungry Owl All-Night Grocers          19
# 5            Berglunds snabbköp          18
# 6              HILARION-Abastos          18
# 7    Rattlesnake Canyon Grocery          18
# 8                      Bon app'          17
# 9                Frankenversand          15

# %%
sns.catplot(x='CategoryName',
               y='QuantitySold',
               data=df_product_analysis_1.sort_values('QuantitySold', ascending=False),
               kind='bar')
plt.show()

# %%
df_product_analysis_1['Revenue'] = df_product_analysis_1['Revenue'].str.replace(',','.').astype(float)
sns.catplot(x='CategoryName',
               y='Revenue',
               data=df_product_analysis_1.sort_values('Revenue', ascending=False),
               kind='bar')
plt.show()

# %%
sns.catplot(x='TotalQuantitySold',
               y='ProductName',
               data=df_product_analysis_2,
               kind='bar')
plt.show()

# %%
df_customer_analysis_1['Revenue'] = df_customer_analysis_1['Revenue'].str.replace(',','.').astype(float)
plt.pie(df_customer_analysis_1['Revenue'],
        labels=df_customer_analysis_1['Country'],
        autopct='%.0f%%')
plt.show()

# %%
sns.catplot(x='OrderCount',
               y='CompanyName',
               data=df_customer_analysis_2,
               kind='bar')
plt.show()
